# %% [markdown]
# Creating DuckDB databases

# %%
import duckdb

conn = duckdb.connect()

# %%
conn

# %%
myconn = duckdb.connect(database='mydb.thanga')

# %%
myconn

# %% [markdown]
# Dataset
#
#
# airlines.csv - a list of american airlines
#
# airports.csv - a list of airports in the US
#
# flights.csv - a list of flight details for various airlines in 2015
